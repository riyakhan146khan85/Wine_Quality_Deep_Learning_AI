# %% [markdown]
# <a href="https://colab.research.google.com/github/riyakhan146khan85/Wine_Quality_Deep_Learning_AI/blob/main/Project_3_Deep_Learning_Neural_Network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
# Corrected URL for a wine quality dataset (e.g., Red Wine Quality)
data_url = "https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv"
wine_df = pd.read_csv(data_url, sep=';', header=0) # Note: Some UCI wine CSVs use ';' as separator
print('Deep learning workspace connected successfully')
print(f'Total multi-dimensional samples tracked: {wine_df.shape[0]}')
print(f'TensorFlow version Active: {tf.__version__}') # Corrected typo
wine_df.head()
# Out:
# Deep learning workspace connected successfully
# Total multi-dimensional samples tracked: 1599
# TensorFlow version Active: 2.20.0
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
x = wine_df.drop(columns=['quality'])
y = wine_df['quality']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)
print('Data split and scaled cleanly!')
print(f'Training data shape: {x_train_scaled.shape}')
print(f'Testing data shape: {x_test_scaled.shape}')
# Out:
# Data split and scaled cleanly!
# Training data shape: (1279, 11)
# Testing data shape: (320, 11)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
model = Sequential()
model.add(Dense(64, activation='relu', input_shape=(x_train_scaled.shape[1],)))
model.add(Dense(32, activation='relu'))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')
print('Deep neural network architechture compiled perfect!')
print(model.summary())
# Out:
# Deep neural network architechture compiled perfect!
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                 │ (None, 64)             │           768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
history = model.fit(x_train_scaled, y_train, epochs=50, batch_size=32, validation_split=0.2)
print('Deep neural network trained successfully!')
# Out:
# Epoch 1/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 18.9353 - val_loss: 9.9266
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.3742 - val_loss: 3.1264
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.0543 - val_loss: 2.3189
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.1512 - val_loss: 2.0391
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.8044 - val_loss: 1.8687
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6194 - val_loss: 1.7104
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4639 - val_loss: 1.5508
# Epoch 8/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3325 - val_loss: 1.4528
# Epoch 9/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2301 - val_loss: 1.3363
# Epoch 10/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1478 - val_loss: 1.2501
# Epoch 11/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0619 - val_loss: 1.1658
# Epoch 12/50
# ...

# %%
test_loss = model.evaluate(x_test_scaled, y_test)
print(f'Test Loss (MSE): {test_loss:.4f}')
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3802
# Test Loss (MSE): 0.3802

# %%
import numpy as np
custom_wine_profile = np.array([[7.4, 0.25, 0.36, 2.0, 0.067, 15.0, 45.0, 0.9954, 3.25, 0.68, 12.5]])
custom_wine_profile_scaled = scaler.transform(custom_wine_profile)
predicted_quality = model.predict(custom_wine_profile_scaled)
final_score = predicted_quality[0][0]
print('\n---xAI Ecology assistant evalution---')
print(f'Predicted Wine Quality: {predicted_quality[0][0]:.2f} / 10.0')
if final_score >= 6.5:
  print('DECISION: PREMIUM QUALITY PROFILE DETECTED! ARCHIEVE FOR VINTAGE RELEASE.')
else:
  print('DECISION: STANDARD QUALITY PROFILE DETECTED. ALLOCATE TO MASS COMMERCE BLENDS.')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
#
# ---xAI Ecology assistant evalution---
# Predicted Wine Quality: 6.74 / 10.0
# DECISION: PREMIUM QUALITY PROFILE DETECTED! ARCHIEVE FOR VINTAGE RELEASE.
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
